# %%
import glob
import shutil
from pathlib import Path

subjects_with_fp_in_training = ["psma_f77011649a56cf08_2021-06-26",
"psma_b487a97686e64dbf_2019-11-18",
"fdg_adc49adb3d_09-22-2002-NA-PET-CT_Ganzkoerper__primaer_mit_KM-59119",
"psma_f77011649a56cf08_2021-02-27",
"psma_18eba3b35ee1ddac_2019-06-08",
"psma_b487a97686e64dbf_2019-07-08",
"psma_ee01cba36afe0f56_2022-05-21",
"psma_4da96443cf212c5f_2022-05-14",
"psma_f46740fcc3f44f10_2020-05-22"
]

tp = [0, 
90,
0,
0,
140,
127,
0,
0,
33
]



# Define the destination directory
dest_dir = Path("images_for_further_evaluation")
dest_dir.mkdir(exist_ok=True)

for subject in subjects_with_fp_in_training:
    # Locate PET file
    pet = glob.glob(
        f"/mnt/nfs/slow_ai_team/organ_segmentation/nnunet_liverv0.0/nnUNet_raw_database/nnUNet_raw/nnUNet_raw_data/Dataset020_AutoPET2024_Regions/imagesTr/{subject}*_0001.nii.gz"
    )[0]
    print(f"Copying PET: {pet}")
    # Locate PET file
    ct = glob.glob(
        f"/mnt/nfs/slow_ai_team/organ_segmentation/nnunet_liverv0.0/nnUNet_raw_database/nnUNet_raw/nnUNet_raw_data/Dataset020_AutoPET2024_Regions/imagesTr/{subject}*_0000.nii.gz"
    )[0]
    print(f"Copying CT: {ct}")


    # Locate SEG file
    seg = glob.glob(
        f"/mnt/nfs/slow_ai_team/organ_segmentation/nnunet_liverv0.0/nnUNet_raw_database/nnUNet_raw/nnUNet_raw_data/Dataset020_AutoPET2024_Regions/labelsTr/{subject}*.nii.gz"
    )[0]
    print(f"Copying SEG: {seg}")

    # Copy PET file to destination directory
    shutil.copy(pet, dest_dir / Path(pet).name)

    # Copy SEG file to destination directory
    shutil.copy(ct, dest_dir / Path(ct).name)    

    # Copy SEG file to destination directory
    shutil.copy(seg, dest_dir / Path(seg).name)
# Out:
# Copying PET: /mnt/nfs/slow_ai_team/organ_segmentation/nnunet_liverv0.0/nnUNet_raw_database/nnUNet_raw/nnUNet_raw_data/Dataset020_AutoPET2024_Regions/imagesTr/psma_f77011649a56cf08_2021-06-26_0001.nii.gz
# Copying CT: /mnt/nfs/slow_ai_team/organ_segmentation/nnunet_liverv0.0/nnUNet_raw_database/nnUNet_raw/nnUNet_raw_data/Dataset020_AutoPET2024_Regions/imagesTr/psma_f77011649a56cf08_2021-06-26_0000.nii.gz
# Copying SEG: /mnt/nfs/slow_ai_team/organ_segmentation/nnunet_liverv0.0/nnUNet_raw_database/nnUNet_raw/nnUNet_raw_data/Dataset020_AutoPET2024_Regions/labelsTr/psma_f77011649a56cf08_2021-06-26.nii.gz
# Copying PET: /mnt/nfs/slow_ai_team/organ_segmentation/nnunet_liverv0.0/nnUNet_raw_database/nnUNet_raw/nnUNet_raw_data/Dataset020_AutoPET2024_Regions/imagesTr/psma_b487a97686e64dbf_2019-11-18_0001.nii.gz
# ...

# %%
CLE = [
    "/mnt/nfs/slow_ai_team/organ_segmentation/nnunet_liverv0.0/nnUNet_raw_database/nnUNet_raw/nnUNet_raw_data/Dataset019_AutoPET2024/confidence_estimates/fdg_3b26172779_11-10-2001-NA-PET-CT_Ganzkoerper__primaer_mit_KM-21405.nii.gz",
    "/mnt/nfs/slow_ai_team/organ_segmentation/nnunet_liverv0.0/nnUNet_raw_database/nnUNet_raw/nnUNet_raw_data/Dataset019_AutoPET2024/confidence_estimates/fdg_3c94a00f90_05-11-2007-NA-PET-CT_Ganzkoerper__primaer_mit_KM-83405.nii.gz",
    "/mnt/nfs/slow_ai_team/organ_segmentation/nnunet_liverv0.0/nnUNet_raw_database/nnUNet_raw/nnUNet_raw_data/Dataset019_AutoPET2024/confidence_estimates/fdg_3d6f425a76_01-28-2002-NA-PET-CT_Ganzkoerper__primaer_mit_KM-67631.nii.gz",
    "/mnt/nfs/slow_ai_team/organ_segmentation/nnunet_liverv0.0/nnUNet_raw_database/nnUNet_raw/nnUNet_raw_data/Dataset019_AutoPET2024/confidence_estimates/psma_53c3a9d0f51745b6_2017-12-24.nii.gz",
    
]
